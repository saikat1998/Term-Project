# %%
import pandas as pd
import pytesseract
import cv2
from PIL import Image
from PIL import ImageDraw
import matplotlib.pyplot as plt
import re

# %%
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

# %%
img = cv2.imread("page0.jpg")
data = pytesseract.image_to_string(img)
print(data)
plt.imshow(img)
# Out:
# La
#
# Xinduring Value
#
# Balance Sheet as at 31st March, 2022
#
# Asat Asat
# Note 31st March, 2022 Sst March, 2021
# (in Crores) in Crores)
# ASSETS
# Non-current assets
# (@) Property, Pant and Equipment EN 9550.15 TS50287
# (B) Capital work-in-progress 3B 2483.34 3329.97
# (c) Investment Property 3G 364.20 376.56
# (@) Goodwill 3D 577.20 377.20
# (@) Other Intangible assets 3E 2007.22. 2004.32
# (()_Other intangible assets under development a PERT 350
# (g) Right of use assets 3G 712.84 726.84
# (h) Financial Assets
# ()_ Investments 4 15657.32. 12937.42
# Loans 3 5.06 237
# i) Others 6 1572.40 17234,78 72.45 1301224
# (i) Other non-current assets 7 1228.92 44150.49 | 4231.62 39765.12
# Current assets
# (a) Inventories B 9097.77 3470.87
# (b) Financial Assets.
# ()_Thvestments 9 11624.95 1404677
# Trade receivables 70 1952.50 2090.29
# Cash and cash equivalents T1__184.97 231.28
# ((v) Other Bank Balances 12 3692.97 3770.25
# (v) Loans 5 5.73 277
# ...

# %%
# function to display the coordinates of
# of the points clicked on the image
def click_event(event, x, y, flags, params):
 
    # checking for left mouse clicks
    if event == cv2.EVENT_LBUTTONDOWN:
 
        # displaying the coordinates
        # on the Shell
        print(x, ' ', y)
 
        # displaying the coordinates
        # on the image window
        font = cv2.FONT_HERSHEY_SIMPLEX
        cv2.putText(img, str(x) + ',' +
                    str(y), (x,y), font,
                    1, (255, 0, 0), 2)
        cv2.imshow('image', img)
 
    # checking for right mouse clicks    
    if event==cv2.EVENT_RBUTTONDOWN:
 
        # displaying the coordinates
        # on the Shell
        print(x, ' ', y)
 
        # displaying the coordinates
        # on the image window
        font = cv2.FONT_HERSHEY_SIMPLEX
        b = img[y, x, 0]
        g = img[y, x, 1]
        r = img[y, x, 2]
        cv2.putText(img, str(b) + ',' +
                    str(g) + ',' + str(r),
                    (x,y), font, 1,
                    (255, 255, 0), 2)
        cv2.imshow('image', img)
 
# driver function
if __name__=="__main__":
 
    # reading the image
    img = cv2.imread('page0.jpg', 1)
 
    # displaying the image
    cv2.imshow('image', img)
 
    # setting mouse handler for the image
    # and calling the click_event() function
    cv2.setMouseCallback('image', click_event)
 
    # wait for a key to be pressed to exit
    cv2.waitKey(0)
 
    # close the window
    cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-80-3447d507f347> in <module>
#      44
#      45     # displaying the image
# ---> 46     cv2.imshow('image', img)
#      47
#      48     # setting mouse handler for the image
#
# error: OpenCV(4.5.4) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:1274: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvShowImage'

# %%
im1 = Image.open('page0.jpg').convert('L')
im1 = im1.crop((51, 272, 400, 375))
im1.save('Non-current assets.jpg')

# %%
img1 = cv2.imread("Non-current assets.jpg")
data1 = pytesseract.image_to_string(img1)
print(data1)
# Out:
# {a) Property, Plant and Equipment 3A
# (b)_Capital work-in-progress 3B
# (@) Investment Property aC.
# (4) Goodwill ED}
# (e) Other Intangible assets 3E
# (Other intangible assets under development __3F
# tq) Righl of use esects: 3G

# %%
s = data1.split("\n")
s
# Out:
# ['{a) Property, Plant and Equipment 3A',
#  '(b)_Capital work-in-progress 3B',
#  '(@) Investment Property aC.',
#  '(4) Goodwill ED}',
#  '(e) Other Intangible assets 3E',
#  '(Other intangible assets under development __3F',
#  'tq) Righl of use esects: 3G',
#  '']

# %%
s.pop()
# Out:
# ''

# %%
s
# Out:
# ['{a) Property, Plant and Equipment 3A',
#  '(b)_Capital work-in-progress 3B',
#  '(@) Investment Property aC.',
#  '(4) Goodwill ED}',
#  '(e) Other Intangible assets 3E',
#  '(Other intangible assets under development __3F',
#  'tq) Righl of use esects: 3G']

# %%
im2 = Image.open('page0.jpg').convert('L')
im2 = im2.crop((51, 376, 369, 449))
im2.save('NC-Financial-assets.jpg')

# %%
img2 = cv2.imread("NC-Financial-assets.jpg")
data2 = pytesseract.image_to_string(img2)
print(data2)
# Out:
# (h) Financial Assets
#
# (@_Investments
#
# 1) Other non-current assets

# %%
im3 = Image.open('page0.jpg').convert('L')
im3 = im3.crop((51,482, 369, 620))
im3.save('C-Financial-assets.jpg')

# %%
img3 = cv2.imread("C-Financial-assets.jpg")
data3 = pytesseract.image_to_string(img3)
print(data3)
# Out:
# (b) Financial Assets
#
# @_Investments
#
# i) Trade receivables
#
# i) Cash and cash equivalents:
#
# (iv) Other Bank Balances
#
# v) Loans
#
# (vi) Others.
#
# (@) Other current assets
#
# TOTAL ASSETS

# %%
im4 = Image.open('page0.jpg').convert('L')
im4 = im4.crop((400, 272, 606, 375))
im4.save('NCA-price.jpg')

# %%
img4 = cv2.imread("NCA-price.jpg")
data4 = pytesseract.image_to_string(img4)
print(data4)
# Out:
# 19559.15
# 2442.34
# 364.20
# 577.20
# 2007.22
# 23.84
# 7i2B4

# %%
r = data4.split('\n')
r
# Out:
# ['19559.15', '2442.34', '364.20', '577.20', '2007.22', '23.84', '7i2B4', '']

# %%
r.pop()
# Out:
# ''

# %%
im5 = Image.open('page0.jpg').convert('L')
im5 = im5.crop((400, 375, 606, 448))
im5.save('page_4.jpg')

# %%
img5 = cv2.imread("page_4.jpg")
data5 = pytesseract.image_to_string(img5)
print(data5)
# Out:
# 15657.82
# 5.06
# 1572.40 _17234,78
# 7208.92 4415049

# %%
dframe = {"Non-current assets":s, "NCA-price":r}

# %%
pd.DataFrame(dframe)
# Out:
#                                 Non-current assets NCA-price
# 0             {a) Property, Plant and Equipment 3A  19559.15
# 1                  (b)_Capital work-in-progress 3B   2442.34
# 2                      (@) Investment Property aC.    364.20
# 3                                 (4) Goodwill ED}    577.20
# 4                   (e) Other Intangible assets 3E   2007.22
# 5  (Other intangible assets under development __3F     23.84
# 6                      tq) Righl of use esects: 3G     7i2B4

# %%
im7 = Image.open('page0.jpg').convert('L')
im7 = im7.crop((41, 236, 400, 1025))
im7.save('heading.jpg')

# %%
img7 = cv2.imread("heading.jpg")
data7 = pytesseract.image_to_string(img7)
print(data7)
# Out:
# ASSETS
# Non-current assets
#
# (a) Property, Plant and Equipment 3A
# (b)_ Capital work-in-progress 3B
# (c) Investment Property EG
# (a) Goodwill 3D)
# (e) Other Intangible assets BE
# (Other intangible assets under development _3F"
# (g) Right of use assets 3G
#
# (h) Financial Assets
#
# (@_Investments
#
# i) Others
#
# ry
# Loans 3
# 6
# z
#
# (_ Other non-current assets
#
# Current assets
#
# (a) Inventories S
# (b) Financial Assets
# @_Investments a
#
# Trade receivables 70
#
# )) Cash and cash equivalents it
# (iv) Other Bank Balances 12
# (W) Loans 5
# (vi) Others. 6
# (@) Other current assets 7
#
# TOTAL ASSETS
# EQUITY AND LIABILITIES
# Equity
#
# (a) Equity Share capital ie
#
# (b) Other Equity
#
# Liabilities
#
# Non-current labilities
#
# (@) Financial Liabilities
#
# @_Borrowings 4
#
# Lease Liabilities 15
#
# i) Other financial lables 16
# (B) Provisions, 7
# (©) Deferred tax abilities (Net) 18
#
# Current liabilities
#
# (a) Financial Liabilities
#
# ...

# %%
a = data7.split("\n")
a
#len(a)
# Out:
# ['ASSETS',
#  'Non-current assets',
#  '',
#  '(a) Property, Plant and Equipment 3A',
#  '(b)_ Capital work-in-progress 3B',
#  '(c) Investment Property EG',
#  '(a) Goodwill 3D)',
#  '(e) Other Intangible assets BE',
#  '(Other intangible assets under development _3F"',
#  '(g) Right of use assets 3G',
#  '',
#  '(h) Financial Assets',
#  '',
#  '(@_Investments',
#  '',
#  'i) Others',
#  '',
#  'ry',
#  'Loans 3',
#  '6',
#  'z',
#  '',
#  '(_ Other non-current assets',
#  '',
#  'Current assets',
#  '',
#  '(a) Inventories S',
#  '(b) Financial Assets',
#  '@_Investments a',
#  '',
#  'Trade receivables 70',
#  '',
#  ')) Cash and cash equivalents it',
#  '(iv) Other Bank Balances 12',
#  '(W) Loans 5',
#  '(vi) Others. 6',
#  '(@) Other current assets 7',
#  '',
#  'TOTAL ASSETS',
#  'EQUITY AND LIABILITIES',
#  'Equity',
#  '',
#  '(a) Equity Share capital ie',
#  '',
#  '(b) Other Equity',
#  '',
#  'Liabilities',
#  '',
#  'Non-current labilities',
#  '',
# ...

# %%
a1 = [y for y in a if y]
a1
# Out:
# ['ASSETS',
#  'Non-current assets',
#  '(a) Property, Plant and Equipment 3A',
#  '(b)_ Capital work-in-progress 3B',
#  '(c) Investment Property EG',
#  '(a) Goodwill 3D)',
#  '(e) Other Intangible assets BE',
#  '(Other intangible assets under development _3F"',
#  '(g) Right of use assets 3G',
#  '(h) Financial Assets',
#  '(@_Investments',
#  'i) Others',
#  'ry',
#  'Loans 3',
#  '6',
#  'z',
#  '(_ Other non-current assets',
#  'Current assets',
#  '(a) Inventories S',
#  '(b) Financial Assets',
#  '@_Investments a',
#  'Trade receivables 70',
#  ')) Cash and cash equivalents it',
#  '(iv) Other Bank Balances 12',
#  '(W) Loans 5',
#  '(vi) Others. 6',
#  '(@) Other current assets 7',
#  'TOTAL ASSETS',
#  'EQUITY AND LIABILITIES',
#  'Equity',
#  '(a) Equity Share capital ie',
#  '(b) Other Equity',
#  'Liabilities',
#  'Non-current labilities',
#  '(@) Financial Liabilities',
#  '@_Borrowings 4',
#  'Lease Liabilities 15',
#  'i) Other financial lables 16',
# ...

# %%
a2 = [x for x in a1 if len(x) >= 6 ]
a2
# Out:
# ['ASSETS',
#  'Non-current assets',
#  '(a) Property, Plant and Equipment 3A',
#  '(b)_ Capital work-in-progress 3B',
#  '(c) Investment Property EG',
#  '(a) Goodwill 3D)',
#  '(e) Other Intangible assets BE',
#  '(Other intangible assets under development _3F"',
#  '(g) Right of use assets 3G',
#  '(h) Financial Assets',
#  '(@_Investments',
#  'i) Others',
#  'Loans 3',
#  '(_ Other non-current assets',
#  'Current assets',
#  '(a) Inventories S',
#  '(b) Financial Assets',
#  '@_Investments a',
#  'Trade receivables 70',
#  ')) Cash and cash equivalents it',
#  '(iv) Other Bank Balances 12',
#  '(W) Loans 5',
#  '(vi) Others. 6',
#  '(@) Other current assets 7',
#  'TOTAL ASSETS',
#  'EQUITY AND LIABILITIES',
#  'Equity',
#  '(a) Equity Share capital ie',
#  '(b) Other Equity',
#  'Liabilities',
#  'Non-current labilities',
#  '(@) Financial Liabilities',
#  '@_Borrowings 4',
#  'Lease Liabilities 15',
#  'i) Other financial lables 16',
#  '(B) Provisions, 7',
# ...

# %%
a3 = re.findall("\(.\).*", a2)
a3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-7be5e720aefa> in <module>
# ----> 1 a3 = re.findall("\(.\).*", a2)
#       2 a3
#
# ~\anaconda3\lib\re.py in findall(pattern, string, flags)
#     239
#     240     Empty matches are included in the result."""
# --> 241     return _compile(pattern, flags).findall(string)
#     242
#     243 def finditer(pattern, string, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
[re.findall("\(.*", a) for a in a2]
# Out:
# [[],
#  [],
#  ['(a) Property, Plant and Equipment 3A'],
#  ['(b)_ Capital work-in-progress 3B'],
#  ['(c) Investment Property EG'],
#  ['(a) Goodwill 3D)'],
#  ['(e) Other Intangible assets BE'],
#  ['(Other intangible assets under development _3F"'],
#  ['(g) Right of use assets 3G'],
#  ['(h) Financial Assets'],
#  ['(@_Investments'],
#  [],
#  [],
#  ['(_ Other non-current assets'],
#  [],
#  ['(a) Inventories S'],
#  ['(b) Financial Assets'],
#  [],
#  [],
#  [],
#  ['(iv) Other Bank Balances 12'],
#  ['(W) Loans 5'],
#  ['(vi) Others. 6'],
#  ['(@) Other current assets 7'],
#  [],
#  [],
#  [],
#  ['(a) Equity Share capital ie'],
#  ['(b) Other Equity'],
#  [],
#  [],
#  ['(@) Financial Liabilities'],
#  [],
#  [],
#  [],
#  ['(B) Provisions, 7'],
#  ['(©) Deferred tax abilities (Net) 18'],
#  [],
#  ['(a) Financial Liabilities'],
#  ['()_ Borrowings 14'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['(iv) Other financial iabiiies 16'],
# ...

# %%
d = {"content":a2}

# %%
pd.DataFrame(d)
# Out:
#                                             content
# 0                                            ASSETS
# 1                                Non-current assets
# 2              (a) Property, Plant and Equipment 3A
# 3                  (b)_ Capital work-in-progress 3B
# 4                        (c) Investment Property EG
# 5                                  (a) Goodwill 3D)
# 6                    (e) Other Intangible assets BE
# 7   (Other intangible assets under development _3F"
# 8                        (g) Right of use assets 3G
# 9                              (h) Financial Assets
# 10                                   (@_Investments
# 11                                        i) Others
# 12                                          Loans 3
# 13                      (_ Other non-current assets
# 14                                   Current assets
# 15                                (a) Inventories S
# 16                             (b) Financial Assets
# ...

# %%
bs1 = re.findall("\(.\).*", data7)
bs1
# Out:
# ['(a) Property, Plant and Equipment 3A',
#  '(b)_ Capital work-in-progress 3B',
#  '(c) Investment Property EG',
#  '(a) Goodwill 3D)',
#  '(e) Other Intangible assets BE',
#  '(g) Right of use assets 3G',
#  '(h) Financial Assets',
#  '(a) Inventories S',
#  '(b) Financial Assets',
#  '(W) Loans 5',
#  '(@) Other current assets 7',
#  '(a) Equity Share capital ie',
#  '(b) Other Equity',
#  '(@) Financial Liabilities',
#  '(B) Provisions, 7',
#  '(©) Deferred tax abilities (Net) 18',
#  '(a) Financial Liabilities',
#  '(c) Provisions 17',
#  '(@) Current Tax Liabiities (Nat) 20']

# %%
im8 = Image.open('page0.jpg').convert('L')
im8 = im8.crop((400, 236, 606, 1025))
im8.save('pricing_2022.jpg')

# %%
img8 = cv2.imread("pricing_2022.jpg")
data8 = pytesseract.image_to_string(img8)
print(data8)
# Out:
# T8550.15
#
# 2442.34
# 364.20
# 877.20
# 2007.22
# 23.84
# 712.84
# 15657.32
# 5.06
# 1572.40 _17234,78
# 1208.92
# 9907.77
# T6245
# 1952.50
# 184.97
# 3692.97
# 3.75
# 2287.97 _19749,09
# 1195.15
# 1282.83
# 0167.24
# Ta
# 259.79
# 96.50 60.85
# 186.87
# 1667.14
# O74
# 100.96
# 4122.44
# 46.09)
# 1503.59 5778.82
# 5097.28
# 55.60.
# 551.39
#
# aa150.49
#
# 30942.01
# 7509250
#
# 61390.57
#
# 2214.84
#
# T1478.05
# 75092.50

# %%
b = data8.split("\n")
b
#len(b)
# Out:
# ['T8550.15',
#  '',
#  '2442.34',
#  '364.20',
#  '877.20',
#  '2007.22',
#  '23.84',
#  '712.84',
#  '15657.32',
#  '5.06',
#  '1572.40 _17234,78',
#  '1208.92',
#  '9907.77',
#  'T6245',
#  '1952.50',
#  '184.97',
#  '3692.97',
#  '3.75',
#  '2287.97 _19749,09',
#  '1195.15',
#  '1282.83',
#  '0167.24',
#  'Ta',
#  '259.79',
#  '96.50 60.85',
#  '186.87',
#  '1667.14',
#  'O74',
#  '100.96',
#  '4122.44',
#  '46.09)',
#  '1503.59 5778.82',
#  '5097.28',
#  '55.60.',
#  '551.39',
#  '',
#  'aa150.49',
#  '',
#  '30942.01',
#  '7509250',
#  '',
#  '61390.57',
#  '',
#  '2214.84',
#  '',
#  'T1478.05',
#  '75092.50',
#  '']

# %%
b1 = [x for x in b if x]
b1
# Out:
# ['T8550.15',
#  '2442.34',
#  '364.20',
#  '877.20',
#  '2007.22',
#  '23.84',
#  '712.84',
#  '15657.32',
#  '5.06',
#  '1572.40 _17234,78',
#  '1208.92',
#  '9907.77',
#  'T6245',
#  '1952.50',
#  '184.97',
#  '3692.97',
#  '3.75',
#  '2287.97 _19749,09',
#  '1195.15',
#  '1282.83',
#  '0167.24',
#  'Ta',
#  '259.79',
#  '96.50 60.85',
#  '186.87',
#  '1667.14',
#  'O74',
#  '100.96',
#  '4122.44',
#  '46.09)',
#  '1503.59 5778.82',
#  '5097.28',
#  '55.60.',
#  '551.39',
#  'aa150.49',
#  '30942.01',
#  '7509250',
#  '61390.57',
#  '2214.84',
#  'T1478.05',
#  '75092.50']

# %%
len(b1)
# Out:
# 41

# %%
g = {"topic":a, "price":b}

# %%
pd.DataFrame(g)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-9c4a06ef80e0> in <module>
# ----> 1 pd.DataFrame(g)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# --> 287     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     288
#     289
#
# ...

# %%
import easyocr
reader = easyocr.Reader(['en'])
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
img = Image.open("heading.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=359x789 at 0x1EFFC1CD460>

# %%
bounds = reader.readtext("heading.jpg")
bounds
# Out:
# [([[9, 1], [65, 1], [65, 17], [9, 17]], 'ASSETS', 0.99987424272407),
#  ([[9, 21], [131, 21], [131, 35], [9, 35]],
#   'Non-current assets',
#   0.9987661230665393),
#  ([[53, 37], [105, 37], [105, 51], [53, 51]], 'Property', 0.9940587560894293),
#  ([[111, 37], [167, 37], [167, 51], [111, 51]],
#   'Plant and',
#   0.882286312128158),
#  ([[180, 40], [230, 40], [230, 48], [180, 48]],
#   'quidMen',
#   0.27065203679576205),
#  ([[53, 53], [93, 53], [93, 67], [53, 67]], 'Capua', 0.862231451061175),
#  ([[98, 54], [140, 54], [140, 62], [98, 62]], 'Work-m', 0.2041211922877505),
#  ([[170, 54], [196, 54], [196, 62], [170, 62]], 'Tese', 0.4499281346797943),
#  ([[51, 67], [173, 67], [173, 81], [51, 81]],
#   'Inveslment Property',
#   0.6493078105446429),
#  ([[64, 84], [94, 84], [94, 92], [64, 92]], 'Ooc', 0.3045341863093026),
#  ([[91, 97], [191, 97], [191, 111], [91, 111]],
#   'Intangible assets',
#   0.6877860518639649),
# ...

# %%
def draw_boxes(image, bounds, color = 'red', width = 1):
    draw = ImageDraw.Draw(image)
    for bound in bounds:
        a0,a1,a2,a3 = bound[0]
        draw.line([*a0,*a1,*a2,*a3,*a0], fill = color, width = width)
    return image

# %%
draw_boxes(img, bounds)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=359x789 at 0x1EFFC1CD460>

# %%
bounds = reader.readtext("heading.jpg", contrast_ths = 0.05, adjust_contrast = 0.7, add_margin = 0.45, width_ths = 0.7,
                         decoder = "beamsearch")
bounds
# Out:
# [([[4, 0], [70, 0], [70, 22], [4, 22]], 'ASSETS', 0.9974581266575179),
#  ([[5, 17], [135, 17], [135, 39], [5, 39]],
#   'Non-current assets',
#   0.9966325405186901),
#  ([[49, 33], [171, 33], [171, 55], [49, 55]],
#   'Properly Plantand',
#   0.5415399535076071),
#  ([[177, 37], [233, 37], [233, 51], [177, 51]],
#   'quipmenl',
#   0.8729784061576245),
#  ([[49, 49], [97, 49], [97, 71], [49, 71]], 'Capual', 0.2846970181239312),
#  ([[95, 51], [143, 51], [143, 65], [95, 65]], 'work-in', 0.8209366071697224),
#  ([[167, 51], [199, 51], [199, 65], [167, 65]], 'Tress', 0.9542607549554535),
#  ([[47, 63], [177, 63], [177, 85], [47, 85]],
#   'Inveslment Properly _',
#   0.3982857782516029),
#  ([[61, 81], [97, 81], [97, 95], [61, 95]], 'oodw', 0.20572051027488886),
#  ([[87, 93], [195, 93], [195, 115], [87, 115]],
#   'Intangible assets _',
#   0.772601532771259),
#  ([[49, 107], [315, 107], [315, 129], [49, 129]],
#   'Oiherintangble assets under developmeni',
#   0.19058205261425762),
# ...
